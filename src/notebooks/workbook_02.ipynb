# %% [markdown]
# ### Workbook - 02

# %%
data = [(1, 'John', '123-456-7890'), (2, 'Jane', '987-654-3210'), (3, 'Bob', '555-123-4567')]
shema = "id int, name string, phone string"
df = spark.createDataFrame(data, shema)
display(df)
