# %% [markdown]
# ### Workbook - 01

# %%
import app_config as app

# %%
data = [
    (100, 'Saravanan', '9600142808'),
    (101, 'Siddharth', '9876739001')
]
schema = "id INT, name STRING, phone STRING"
df = spark.createDataFrame(data, schema=schema)
display(df)

# %%
print(f"Server Name: {app.SERVER_NAME}")
print(f"Operating System: {app.OPERATING_SYSTEM}")
print(f"Environment: {app.ENVIRONMENT}")
